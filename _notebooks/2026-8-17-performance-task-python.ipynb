# %% [raw]
# ---
# layout: post
# title: Performance Task Creation - Python
# description: CPT concepts with multiple Python code runner examples for a watch-themed project
# type: issues
# courses: { csp: {week: 1} }
# comments: true
# permalink: /csp/performance-creation-python
# ---

# %% [markdown]
# # Performance Task - Python CPT Concepts
#
# This notebook contains multiple code runner examples for a watch-themed CPT project.
#
# Each example demonstrates one or more AP CSP concepts required for the Create Performance Task.
#
# ## Output
#
# Output means displaying information to the user via print() statements.
#
# {% include code-runner.html
#    runner_id="cpt_output"
#    language="python"
#    challenge="Display the watch catalog parts"
#    code="watch_catalog = ['case', 'dial', 'hands', 'crown', 'movement', 'strap']
#
# print('Watch catalog:')
# for item in watch_catalog:
#     print('-', item)
#
# print('\nA watch has multiple important parts.')"
# %}
#
# ## Input
#
# Input means getting data from the user via input() statements.
#
# {% include code-runner.html
#    runner_id="cpt_input"
#    language="python"
#    challenge="Ask the user which watch part they want to learn about"
#    code="watch_parts = ['case', 'dial', 'hands', 'crown', 'movement', 'strap']
# info = {
#     'case': 'Protects the movement and holds the watch together.',
#     'dial': 'Shows the time and often includes markers or numbers.',
#     'hands': 'Point to the current hour, minute, and second.',
#     'crown': 'Used to set the time and wind a mechanical watch.',
#     'movement': 'The internal mechanism that keeps time.',
#     'strap': 'The band that holds the watch on the wrist.'
# }
#
# part = input('Enter a watch part to learn about: ').strip().lower()
#
# if part == '':
#     print('You entered nothing. Here are the watch parts:')
#     for item in watch_parts:
#         print('-', item)
# elif part in info:
#     print(part.capitalize() + ':', info[part])
# else:
#     print('Unknown part. Try:', ', '.join(watch_parts))"
# %}
#
# ## List
#
# A list is a collection of multiple values stored in one variable.
#
# {% include code-runner.html
#    runner_id="cpt_list"
#    language="python"
#    challenge="Store multiple watch products in a list"
#    code="watch_inventory = [
#     'AeroLite 42',
#     'Crest 36',
#     'Nova X',
#     'Heritage M1'
# ]
#
# print('Current inventory:')
# for watch in watch_inventory:
#     print('-', watch)
#
# print('\nTotal watches:', len(watch_inventory))"
# %}
#
# ## Procedure
#
# A procedure (function) is a reusable block of code that can accept parameters and return values.
#
# {% include code-runner.html
#    runner_id="cpt_procedure"
#    language="python"
#    challenge="Create a function to find a watch by name"
#    code="def find_watch(watches, target):
#     for index in range(len(watches)):
#         if watches[index].lower() == target.lower():
#             return index
#     return -1
#
# inventory = ['AeroLite 42', 'Crest 36', 'Nova X', 'Heritage M1']
# search = input('Enter a watch name to search for: ').strip()
# position = find_watch(inventory, search)
#
# if position == -1:
#     print(search, 'was not found in the inventory.')
# else:
#     print(search, 'was found at index', position)"
# %}
#
# ## Sequence
#
# Sequence means statements execute in order, line by line.
#
# {% include code-runner.html
#    runner_id="cpt_sequence"
#    language="python"
#    challenge="Calculate a watch price with tax and shipping"
#    code="watch_price = 120
# tax_rate = 0.08
# shipping = 12
# subtotal = watch_price * 1
# tax = subtotal * tax_rate
# total = subtotal + tax + shipping
#
# print('Watch price:', watch_price)
# print('Tax:', tax)
# print('Shipping:', shipping)
# print('Final total:', total)"
# %}
#
# ## Selection
#
# Selection uses IF/ELSE statements to make decisions based on conditions.
#
# {% include code-runner.html
#    runner_id="cpt_selection"
#    language="python"
#    challenge="Determine watch category based on price"
#    code="price = int(input('Enter the watch price: '))
#
# if price < 100:
#     category = 'Budget'
# elif price < 200:
#     category = 'Mid-range'
# else:
#     category = 'Premium'
#
# print('Watch category:', category)"
# %}
#
# ## Iteration
#
# Iteration uses loops to repeat code for each item in a collection.
#
# {% include code-runner.html
#    runner_id="cpt_iteration"
#    language="python"
#    challenge="Loop through watch inventory and display status"
#    code="inventory = [
#     {'name': 'AeroLite 42', 'price': 120, 'stock': 8},
#     {'name': 'Crest 36', 'price': 90, 'stock': 0},
#     {'name': 'Nova X', 'price': 220, 'stock': 5},
#     {'name': 'Heritage M1', 'price': 310, 'stock': 3}
# ]
#
# for watch in inventory:
#     if watch['stock'] > 0:
#         status = 'available'
#     else:
#         status = 'out of stock'
#     print(watch['name'], '-', '$' + str(watch['price']), '-', status)"
# %}
#
# ## Algorithm
#
# An algorithm combines sequencing, selection, and iteration to solve a meaningful problem.
#
# {% include code-runner.html
#    runner_id="cpt_algorithm"
#    language="python"
#    challenge="Find watches that match the user's budget"
#    code="inventory = [
#     {'name': 'AeroLite 42', 'brand': 'Timex', 'price': 120, 'stock': 8},
#     {'name': 'Crest 36', 'brand': 'Casio', 'price': 90, 'stock': 0},
#     {'name': 'Nova X', 'brand': 'Citizen', 'price': 220, 'stock': 5},
#     {'name': 'Heritage M1', 'brand': 'Seiko', 'price': 310, 'stock': 3}
# ]
#
# budget = int(input('What is your maximum budget? '))
# recommended = []
#
# for watch in inventory:
#     if watch['stock'] > 0 and watch['price'] <= budget:
#         recommended.append(watch['name'])
#
# if len(recommended) == 0:
#     print('No watches fit your budget right now.')
# else:
#     print('Recommended watches:')
#     for item in recommended:
#         print('-', item)"
# %}
#
# ## List Operations
#
# List operations include APPEND (add), INSERT (add at index), REMOVE (delete), and LENGTH (count).
#
# {% include code-runner.html
#    runner_id="cpt_list_ops"
#    language="python"
#    challenge="Demonstrate append, insert, remove, and length"
#    code="watch_list = ['AeroLite 42', 'Crest 36']
# print('Start:', watch_list)
#
# watch_list.append('Nova X')
# print('After append:', watch_list)
#
# watch_list.insert(1, 'Classic 7')
# print('After insert:', watch_list)
#
# watch_list.remove('Crest 36')
# print('After remove:', watch_list)
#
# print('Length:', len(watch_list))"
# %}
#
# ## Search Algorithm
#
# A search algorithm finds an item in a list. Linear search checks each item until found.
#
# {% include code-runner.html
#    runner_id="cpt_search"
#    language="python"
#    challenge="Implement linear search for watch brands"
#    code="brands = ['Timex', 'Casio', 'Citizen', 'Seiko', 'Omega']
# search_brand = input('Enter a brand to search for: ').strip()
#
# found = False
# for index in range(len(brands)):
#     if brands[index].lower() == search_brand.lower():
#         print(search_brand, 'found at index', index)
#         found = True
#         break
#
# if not found:
#     print(search_brand, 'was not found in the list.')"
# %}
#
# ## Boolean Logic
#
# Boolean logic uses AND, OR, and NOT to combine conditions.
#
# {% include code-runner.html
#    runner_id="cpt_boolean"
#    language="python"
#    challenge="Decide if a watch is a good purchase using boolean logic"
#    code="watch = {
#     'name': 'Nova X',
#     'price': 220,
#     'stock': 5,
#     'brand': 'Citizen'
# }
#
# budget = int(input('Enter your budget: '))
#
# is_affordable = watch['price'] <= budget
# has_stock = watch['stock'] > 0
# is_good_brand = watch['brand'] == 'Citizen' or watch['brand'] == 'Seiko'
#
# if is_affordable and has_stock and is_good_brand:
#     print('This watch is a strong purchase option.')
# else:
#     print('This watch may not be the best choice right now.')"
# %}
#
# ## Summary
#
# This notebook demonstrates all major CPT concepts:
# - **Output** - Print statements
# - **Input** - Get user data
# - **List** - Store collections
# - **Procedure** - Reusable functions
# - **Sequence** - Step-by-step execution
# - **Selection** - IF/ELSE decisions
# - **Iteration** - Loops through data
# - **Algorithm** - Combines multiple concepts
# - **List Operations** - APPEND, INSERT, REMOVE, LENGTH
# - **Search Algorithm** - Find items in lists
# - **Boolean Logic** - AND, OR, NOT conditions
